# %% [markdown]
# <a href="https://colab.research.google.com/github/YashL-495107/font-size-37px-/blob/main/ExoP_AI_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bba52388-f761-46f6-9fb5-12c83715cd93" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bba52388-f761-46f6-9fb5-12c83715cd93">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import joblib
import pandas as pd

model = joblib.load("xgb_kepler_model.pkl")
encoder = joblib.load("label_encoder.pkl")

FEATURES = [
    'koi_period','koi_duration','koi_depth','koi_prad','koi_teq',
    'koi_insol','koi_model_snr','koi_steff','koi_slogg','koi_srad','koi_kepmag'
]

def confidence_to_label(p):
    if p>=0.9: return "very high"
    if p>=0.75: return "high"
    if p>=0.5: return "medium"
    if p>=0.25: return "low"
    return "very low"

def predict_exoplanet(features_dict):
    df = pd.DataFrame([features_dict])[FEATURES]
    pred_numeric = model.predict(df)
    probs = model.predict_proba(df)
    pred_idx = int(pred_numeric[0])
    pred_prob = float(probs[0][pred_idx])
    pred_label = encoder.inverse_transform(pred_numeric)[0]
    return {
        "prediction": pred_label,
        "confidence": pred_prob,
        "confidence_label": confidence_to_label(pred_prob)
    }

# %%
from IPython.display import display
import ipywidgets as widgets

inputs = {}
for feat in FEATURES:
    inputs[feat] = widgets.FloatText(description=feat)
display(*inputs.values())

button = widgets.Button(description="Predict")
output = widgets.Output()

def on_button_click(b):
    with output:
        features = {k: v.value for k,v in inputs.items()}
        result = predict_exoplanet(features)
        print(result)

button.on_click(on_button_click)
display(button, output)
# Out:
# FloatText(value=0.0, description='koi_period')
# FloatText(value=0.0, description='koi_duration')
# FloatText(value=0.0, description='koi_depth')
# FloatText(value=0.0, description='koi_prad')
# FloatText(value=0.0, description='koi_teq')
# FloatText(value=0.0, description='koi_insol')
# FloatText(value=0.0, description='koi_model_snr')
# FloatText(value=0.0, description='koi_steff')
# FloatText(value=0.0, description='koi_slogg')
# FloatText(value=0.0, description='koi_srad')
# FloatText(value=0.0, description='koi_kepmag')
# Button(description='Predict', style=ButtonStyle())
# Output()
